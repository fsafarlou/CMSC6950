# %%
# read data
# %matplotlib inline
import csv
import numpy as np
import matplotlib.pyplot as plt
import requests
import os
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime
import matplotlib.dates as mdates
from matplotlib.pyplot import *
from mpl_toolkits.axes_grid1 import host_subplot
import matplotlib.animation as animation
import matplotlib.pyplot as plt
from IPython.display import HTML
import plotly.express as px

# %%
data_url = "https://health-infobase.canada.ca/src/data/covidLive/covid19.csv"
data_filename = 'Covid19.csv'
#your path should be:

data_path = 'Covid19.csv'

# %%
#data cleaning
#df = df[['testedtoday', 'ratetested', 'numtested']].dropna()
 #df.drop(["numtested"])
    #df=drop.df[df['prname']=='Canada']

# %%
#If the data has not yet been downloaded, download it now
if not os.path.exists(data_filename):
    r = requests.get(data_url, allow_redirects=True)
    open(data_filename, 'wb').write(r.content)

# %%
df = pd.read_csv(data_filename, parse_dates=True, index_col=0)

# %%
df.head(5)
# Out:
#                  prname              prnameFR        date  numconf  numprob  \
# pruid
# 35              Ontario               Ontario  31-01-2020        3        0
# 59     British Columbia  Colombie-Britannique  31-01-2020        1        0
# 1                Canada                Canada  31-01-2020        4        0
# 35              Ontario               Ontario  08-02-2020        3        0
# 59     British Columbia  Colombie-Britannique  08-02-2020        4        0
#
#        numdeaths  numtotal  numtested  numrecover  percentrecover  ratetested  \
# pruid
# 35           0.0         3        NaN         NaN             NaN         NaN
# 59           0.0         1        NaN         NaN             NaN         NaN
# 1            0.0         4        NaN         NaN             NaN         NaN
# 35           0.0         3        NaN         NaN             NaN         NaN
# 59           0.0         4        NaN         NaN             NaN         NaN
#
#        numtoday  percentoday  ratetotal  deathstoday  testedtoday  \
# pruid
# 35          3.0        300.0      0.021          0.0          NaN
# 59          1.0        100.0      0.020          0.0          NaN
# 1           4.0        400.0      0.011          0.0          NaN
# 35          0.0          0.0      0.021          0.0          NaN
# 59          3.0        300.0      0.079          0.0          NaN
#
#        recoveredtoday
# pruid
# 35                NaN
# 59                NaN
# 1                 NaN
# 35                NaN
# 59                NaN

# %%
#df.drop(df.index[1])
fig1 = px.bar(df, x='prname', y='numconf',orientation='v',color='date')
fig1.show()
# Out:
# <div>
#
#
#             <div id="bbeea52c-305b-4a77-b40a-fa8be0ed19f3" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bbeea52c-305b-4a77-b40a-fa8be0ed19f3")) {
#                     Plotly.newPlot(
#                         'bbeea52c-305b-4a77-b40a-fa8be0ed19f3',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=31-01-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=31-01-2020", "marker": {"color": "#636efa"}, "name": "date=31-01-2020", "offsetgroup": "date=31-01-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [3, 1, 4], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=08-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=08-02-2020", "marker": {"color": "#EF553B"}, "name": "date=08-02-2020", "offsetgroup": "date=08-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [3, 4, 7], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=16-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=16-02-2020", "marker": {"color": "#00cc96"}, "name": "date=16-02-2020", "offsetgroup": "date=16-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [3, 5, 8], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=21-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=21-02-2020", "marker": {"color": "#ab63fa"}, "name": "date=21-02-2020", "offsetgroup": "date=21-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [3, 6, 9], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=24-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=24-02-2020", "marker": {"color": "#FFA15A"}, "name": "date=24-02-2020", "offsetgroup": "date=24-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [4, 6, 10], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=25-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=25-02-2020", "marker": {"color": "#19d3f3"}, "name": "date=25-02-2020", "offsetgroup": "date=25-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [4, 7, 11], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=26-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=26-02-2020", "marker": {"color": "#FF6692"}, "name": "date=26-02-2020", "offsetgroup": "date=26-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [5, 7, 12], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=27-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=27-02-2020", "marker": {"color": "#B6E880"}, "name": "date=27-02-2020", "offsetgroup": "date=27-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [6, 7, 13], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=29-02-2020<br>prname=%{x}<br>numconf=%{y}", "legendgroup": "date=29-02-2020", "marker": {"color": "#FF97FF"}, "name": "date=29-02-2020", "offsetgroup": "date=29-02-2020", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Ontario", "British Columbia", "Canada"], "xaxis": "x", "y": [8, 7, 15], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "date=01-03-2020<br>prname=%{x}<br>numconf=%{y}", "legendgr ...

# %%
import plotly.graph_objects as go
fig = go.Figure(go.Scatter(x = df['prname'], y = df['numconf'],
                  name='Share Prices (in USD)'))
fig.show()
# Out:
# <div>
#
#
#             <div id="6027bd14-d022-45b9-9066-d8ba07bcc4eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6027bd14-d022-45b9-9066-d8ba07bcc4eb")) {
#                     Plotly.newPlot(
#                         '6027bd14-d022-45b9-9066-d8ba07bcc4eb',
#                         [{"name": "Share Prices (in USD)", "type": "scatter", "x": ["Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Canada", "Ontario", "British Columbia", "Quebec", "Canada", "Ontario", "British Columbia", "Quebec", "Canada", "Ontario", "British Columbia", "Quebec", "Canada", "Ontario", "British Columbia", "Quebec", "Canada", "Ontario", "British Columbia", "Quebec", "Canada", "Ontario", "British Columbia", "Quebec", "Alberta", "Canada", "Ontario", "British Columbia", "Quebec", "Alberta", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "New Brunswick", "Newfoundland and Labrador", "Nova Scotia", "Prince Edward Island", "Northwest Territories", "Nunavut", "Yukon", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repatriated travellers", "Canada", "British Columbia", "Alberta", "Saskatchewan", "Manitoba", "Ontario", "Quebec", "Newfoundland and Labrador", "New Brunswick", "Nova Scotia", "Prince Edward Island", "Yukon", "Northwest Territories", "Nunavut", "Repat ...

# %%
from matplotlib.pyplot import pie, axis, show

#colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
sums = df.groupby(df["prname"])["numconf"].sum()
axis('equal');
pie(sums,startangle=4, shadow = True,rotatelabels =True,);

plt.legend(labels, bbox_to_anchor=(1,0), loc="lower left", 
                          bbox_transform=plt.gcf().transFigure)

show()
#labels=sums.index
# autopct='%1.1f%%',

# %%
fig = px.line(df, x = 'date', y = 'numconf', title='nothing')
fig.show()
# Out:
# <div>
#
#
#             <div id="61767b4e-2fa8-40bd-82a6-a863993f4be1" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61767b4e-2fa8-40bd-82a6-a863993f4be1")) {
#                     Plotly.newPlot(
#                         '61767b4e-2fa8-40bd-82a6-a863993f4be1',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "date=%{x}<br>numconf=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["31-01-2020", "31-01-2020", "31-01-2020", "08-02-2020", "08-02-2020", "08-02-2020", "16-02-2020", "16-02-2020", "16-02-2020", "21-02-2020", "21-02-2020", "21-02-2020", "24-02-2020", "24-02-2020", "24-02-2020", "25-02-2020", "25-02-2020", "25-02-2020", "26-02-2020", "26-02-2020", "26-02-2020", "27-02-2020", "27-02-2020", "27-02-2020", "29-02-2020", "29-02-2020", "29-02-2020", "01-03-2020", "01-03-2020", "01-03-2020", "01-03-2020", "03-03-2020", "03-03-2020", "03-03-2020", "03-03-2020", "05-03-2020", "05-03-2020", "05-03-2020", "05-03-2020", "06-03-2020", "06-03-2020", "06-03-2020", "06-03-2020", "07-03-2020", "07-03-2020", "07-03-2020", "07-03-2020", "08-03-2020", "08-03-2020", "08-03-2020", "08-03-2020", "08-03-2020", "09-03-2020", "09-03-2020", "09-03-2020", "09-03-2020", "09-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "11-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "12-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "13-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "14-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "15-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "16-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "17-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "18-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "19-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "20-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "21-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "22-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "23-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "24-03-2020", "25-03-2020",  ...

# %%
import seaborn as sns
df[['numconf','numtotal','prname']].plot(kind='bar', stacked=True)
chart = sns.barplot(
    data=df,
    x= df['prname'],
    y = df['numconf'],
    palette='viridis'
)
chart.set(xlabel='Country', ylabel='Confirmed', title = 'Confirmed vs deaths cases in  most affected nations')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Ontario'),
#  Text(0, 0, 'British Columbia'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Quebec'),
#  Text(0, 0, 'Alberta'),
#  Text(0, 0, 'Saskatchewan'),
#  Text(0, 0, 'Manitoba'),
#  Text(0, 0, 'New Brunswick'),
#  Text(0, 0, 'Newfoundland and Labrador'),
#  Text(0, 0, 'Nova Scotia'),
#  Text(0, 0, 'Prince Edward Island'),
#  Text(0, 0, 'Northwest Territories'),
#  Text(0, 0, 'Nunavut'),
#  Text(0, 0, 'Yukon'),
#  Text(0, 0, 'Repatriated travellers')]

# %%
plt.figure(figsize=(20,5))
chart = sns.barplot(
    data=df,
    x= 'prname',
    y = 'ratetotal',
    palette='rainbow'
)
chart.set(xlabel='Prname', ylabel='Total Cases', title = ' Rate of total cases')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Ontario'),
#  Text(0, 0, 'British Columbia'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Quebec'),
#  Text(0, 0, 'Alberta'),
#  Text(0, 0, 'Saskatchewan'),
#  Text(0, 0, 'Manitoba'),
#  Text(0, 0, 'New Brunswick'),
#  Text(0, 0, 'Newfoundland and Labrador'),
#  Text(0, 0, 'Nova Scotia'),
#  Text(0, 0, 'Prince Edward Island'),
#  Text(0, 0, 'Northwest Territories'),
#  Text(0, 0, 'Nunavut'),
#  Text(0, 0, 'Yukon'),
#  Text(0, 0, 'Repatriated travellers')]

# %%
Confirmed = df.groupby(['prname']).sum()
